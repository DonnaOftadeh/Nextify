# %% [markdown]
# ## Nextify Agent Demo
# This notebook asks for a company and product idea, then runs simple agent prompts to refine the idea, research the market, ideate features, and draft a roadmap.

# %%
from agents_demo import idea_refinement, market_research, feature_ideation, roadmap_generation

# %%
company = input('Company name: ')
product = input('Product idea: ')

# %%
print('--- Idea Refinement ---')
print(idea_refinement(company, product))

# %%
print('--- Market Research ---')
print(market_research(company, product))

# %%
print('--- Feature Ideation ---')
print(feature_ideation(company, product))

# %%
print('--- Roadmap ---')
print(roadmap_generation(company, product))
