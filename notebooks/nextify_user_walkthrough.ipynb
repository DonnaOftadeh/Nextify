# %% [markdown]
# # Nextify User Walkthrough
# This notebook demonstrates the MVP workflow for a sample company and product idea.

# %%
def run_workflow(company, product):
    stages = [
        'Idea Refinement',
        'Market Research',
        'Feature Ideation',
        'Roadmap & OKRs'
    ]
    for stage in stages:
        print(f'{stage}: (placeholder output)')

run_workflow('Acme Corp', 'Smart Umbrella')
